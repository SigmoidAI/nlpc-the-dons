# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from nltk import word_tokenize, FreqDist
import seaborn as sns

# %%
date=pd.read_csv('Initial Scraped Data//AppsData.csv')
date.head()
# Out:
#    Unnamed: 0           title                       appId  \
# 0           0   Slice It All!      com.tummygames.sliceit
# 1           1  Hair Challenge  com.Upperpik.HairChallenge
# 2           2     Bridge Race     com.Garawell.BridgeRace
# 3           3       Dice Push          com.jakob.pushdice
# 4           4    Make It Fly!             com.make.it.fly
#
#                                                  url  \
# 0  https://play.google.com/store/apps/details?id=...
# 1  https://play.google.com/store/apps/details?id=...
# 2  https://play.google.com/store/apps/details?id=...
# 3  https://play.google.com/store/apps/details?id=...
# 4  https://play.google.com/store/apps/details?id=...
#
#                                                 icon               developer  \
# 0  https://play-lh.googleusercontent.com/UXBR3KEH...                  VOODOO
# 1  https://play-lh.googleusercontent.com/14aR2z00...            Rollic Games
# 2  https://play-lh.googleusercontent.com/hn0W0fK3...  Supersonic Studios LTD
# 3  https://play-lh.googleusercontent.com/jqHJnmXg...                  VOODOO
# 4  https://play-lh.googleusercontent.com/ydbOTwDq...                 TapNice
#
#               developerId priceText  price  free  \
# 0                  VOODOO      FREE    0.0  True
# 1            Rollic+Games      FREE    0.0  True
# 2  Supersonic+Studios+LTD      FREE    0.0  True
# 3                  VOODOO      FREE    0.0  True
# 4                 TapNice      FREE    0.0  True
#
#                                              summary  scoreText     score  \
# 0                                      Tap to slice!        3.9  3.866412
# 1  Grow your hair longer and win this super fun h...        3.7  3.683039
# 2              Build bridges till the winning stage!        3.5  3.461937
# 3  Play against millions of players and push them...        2.6  2.636792
# 4  Let your imagination and creativity fly wild! ...        4.1  4.107143
#
#   currency
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
# Analiza comparativa la score la free/ paid apps
# prezenta buguri => nota mica
df = pd.DataFrame(date, columns=["priceText","scoreText"])
#numarare 
l=df['scoreText']
AppGratis = FreqDist(l)
# conversie in pandas 
AppGratis=pd.Series(dict(AppGratis))

# %%
#selectare doar aplicatii gratis
gratis=date.loc[date['priceText']=="FREE",['scoreText']]
l=gratis['scoreText']
AppGratis = FreqDist(l)
AppGratis=pd.Series(dict(AppGratis))
numarare=list(AppGratis.values)
scor=list(AppGratis.index)
print(scor)
print(numarare)
# Out:
# [3.9, 3.7, 3.5, 2.6, 4.1, 4.5, 4.3, 4.4, 3.8, 4.0, 4.2, 4.6, 3.4, 4.7, 3.6, 3.3, 4.8, 3.2, 4.9]
# [10, 10, 3, 2, 23, 21, 27, 21, 7, 11, 20, 24, 6, 5, 4, 1, 3, 1, 1]

# %%
#selectare doar aplicatii contra Cost
contraCost=date.loc[date['priceText']!="FREE",['scoreText']]
l=contraCost['scoreText']
AppcuPlata = FreqDist(l)
AppcuPlata=pd.Series(dict(AppcuPlata))
numar=list(AppcuPlata.values)
scorAcordat=list(AppcuPlata.index)
print(scorAcordat)
print(numar)
# Out:
# [4.6, 4.8, 4.3, 4.7, 3.7, 4.5, 4.4, 4.1, 4.2, 3.8, 3.4, 4.9, 3.9, 4.0, 3.6, 3.0, 3.2]
# [22, 19, 25, 29, 6, 30, 22, 8, 18, 4, 2, 6, 2, 4, 1, 1, 1]

# %%
f, (ax1,ax2) = plt.subplots(2, 1, figsize=(15, 7), sharex=True)

sns.barplot(x=scor, y=numarare, palette="rocket", ax=ax1)
ax1.axhline(0, color="k", clip_on=False)
ax1.set_ylabel("Nr. de review-uri")
ax1.set_xlabel("Scor")
sns.barplot(x=scorAcordat, y=numar, palette="rocket", ax=ax2)
ax2.axhline(0, color="k", clip_on=False)
ax2.set_ylabel("Nr. de review-uri")
ax2.set_xlabel("Scor")
# Out:
# Text(0.5, 0, 'Scor')

# %%
# Analiza comparativa la cantitatea de buguri 
# 0->trash 1->bug 2->feature
review=pd.read_csv('D:\\NLP\\dataset\\Reviews_with_label.csv')
review.head()
# Out:
#    Unnamed: 0     userName  score  \
# 0           0       Loquat      5
# 1           1  Skadoosh 69      5
# 2           2  neki0 playz      5
# 3           3   sans 45334      5
# 4           4      Kimmy D      5
#
#                                                  url  \
# 0  https://play.google.com/store/apps/details?id=...
# 1  https://play.google.com/store/apps/details?id=...
# 2  https://play.google.com/store/apps/details?id=...
# 3  https://play.google.com/store/apps/details?id=...
# 4  https://play.google.com/store/apps/details?id=...
#
#                                                 text  thumbsUp  \
# 0                              [ 'good ' , 'game ' ]         1
# 1  [ 'honestli ' , 'favorit ' , 'game ' , 'play '...         0
# 2  [ 'great ' , 'game ' , 'bit ' , 'would ' , 're...         1
# 3                                         [ 'god ' ]         0
# 4                                     [ 'ancient ' ]         0
#
#                                   App_Id  label
# 0  age.of.civilizations2.jakowski.lukasz    0.0
# 1  age.of.civilizations2.jakowski.lukasz    0.0
# 2  age.of.civilizations2.jakowski.lukasz    0.0
# 3  age.of.civilizations2.jakowski.lukasz    0.0
# 4  age.of.civilizations2.jakowski.lukasz    0.0

# %%
label=review['label']
#date null
print(label.isna().sum())
# sterg datele null
label=label.dropna()
#numarare 
statistica = FreqDist(label)
# conversie in pandas 
statistica=pd.Series(dict(statistica))
statistica=list(statistica.values)
nume=['Irrelevant','Bug', 'Feature']
colors=("orange","brown","cyan")
# Wedge properties
wp = { 'linewidth' : 1, 'edgecolor' : "green" }
# Out:
# 106394

# %%
#pie
fig = plt.figure(figsize =(10, 7))
plt.pie(statistica,labels=nume,shadow=True)
plt.show()

# %%
# Aplicatii cu cele mai populare review-uri
date=pd.read_csv('Kaggle Data//googleplaystore_user_reviews.csv')
X= date['App'].values
all_fdist = FreqDist(X).most_common(20) #aplicatiile cu cele mai multe review-uri
all_fdist = pd.Series(dict(all_fdist)) #conversie in pandas

# %%
fig, ax = plt.subplots(figsize=(10,10))
all_plot = sns.barplot(y=all_fdist.index, x=all_fdist.values,orient='h', ax=ax)
plt.title("Frecventa Review: Top 20 Aplicatii")
plt.xlabel("Nr.Review")
plt.ylabel("Nume Aplicatie")
plt.rcParams.update({'font.size': 22})
plt.xticks(rotation=30)
# Out:
# (array([  0.,  50., 100., 150., 200., 250., 300., 350.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# Analiza comparativa la gen de joc 
review=pd.read_csv('Initial Scraped Data//Appsdata_with_genres.csv')
df = pd.DataFrame(review, columns=["developerId","scoreText","Genre2"])
genuri=df["Genre2"]
frecvGenuri = FreqDist(genuri).most_common(20)
frecvGenuri = pd.Series(dict(frecvGenuri)) #conversie in pandas

# %%
fig, ax = plt.subplots(figsize=(10,10))
all_plot = sns.barplot(y=frecvGenuri.index, x=frecvGenuri.values,orient='h', ax=ax)
plt.title("Frecventa Review: Top 20 Genuri de aplicatii")
plt.xlabel("Nr.Aplicatii")
plt.ylabel("Genuri Aplicatie")
plt.rcParams.update({'font.size': 22})
plt.xticks(rotation=30)
# Out:
# (array([ 0.,  5., 10., 15., 20., 25., 30., 35., 40.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
denDezvoltatori=df["developerId"]
frecvDezvoltatori = FreqDist(denDezvoltatori).most_common(20)
frecvDezvoltatori = pd.Series(dict(frecvDezvoltatori)) #conversie in pandas
frecvDezvoltatori
#irrelevant numele dezvoltatorilor
# Out:
# 5394256898986964167                       15
# 6443412597262225303                       10
# VOODOO                                     9
# Supersonic+Studios+LTD                     9
# 6990178528646658622                        8
# 8278886069431493261                        7
# 7086639890153802127                        7
# 8232174611457920989                        6
# SayGames                                   6
# 8684502731112464883                        6
# Warner+Bros.+International+Enterprises     6
# 8026010256970589886                        6
# 6690081412016968981                        5
# 8567646723268777320                        5
# 5630538819012062144                        4
# Fireproof+Games                            4
# 9170275381782328383                        4
# Annapurna+Interactive                      4
# Good+Job+Games                             3
# 7280571841518590348                        3
# dtype: int64
